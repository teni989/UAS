# %%
# !pip install pyserial
# !pip install pydotplus
# !pip install graphviz

# %%
# !pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1321 sha256=d40381c54145c57821e776f589f647485931a78c41400df62eac42fbbb8879b4
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# ...
